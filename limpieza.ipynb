# %%
import pandas as pd

df = pd.read_csv('artificial-intelligence-granted-patents-by-industry.csv')
df.head()
# Out:
#       Entity Code  Year  \
# 0  Argentina  ARG  2013
# 1  Argentina  ARG  2017
# 2  Argentina  ARG  2018
# 3  Argentina  ARG  2019
# 4  Argentina  ARG  2020
#
#    Patent applications granted - Field: Banking and finance  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Patent applications granted - Field: Industry and manufacturing  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Patent applications granted - Field: Energy management  \
# 0                                                  0
# ...

# %%
len(df)
# Out:
# 352

# %%
df.dtypes
# Out:
# Entity                                                                    object
# Code                                                                      object
# Year                                                                       int64
# Patent applications granted - Field: Banking and finance                   int64
# Patent applications granted - Field: Industry and manufacturing            int64
# Patent applications granted - Field: Energy management                     int64
# Patent applications granted - Field: Physical sciences and engineering     int64
# Patent applications granted - Field: Security                              int64
# Patent applications granted - Field: Life sciences                         int64
# Patent applications granted - Field: Transportation                        int64
# Patent applications granted - Field: Business                              int64
# Patent applications granted - Field: Telecommunications                    int64
# ...

# %%
df.shape
# Out:
# (352, 13)

# %%
df2 = pd.read_csv('corporate-investment-in-artificial-intelligence-by-type.csv')
df2.shape
# Out:
# (55, 4)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Entity                             55 non-null     object
#  1   Code                               0 non-null      float64
#  2   Year                               55 non-null     int64
#  3   Global corporate investment in AI  55 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.8+ KB

# %%
df2.dtypes
# Out:
# Entity                                object
# Code                                 float64
# Year                                   int64
# Global corporate investment in AI      int64
# dtype: object

# %%
df2.head()
# Out:
#                 Entity  Code  Year  Global corporate investment in AI
# 0   Merger/acquisition   NaN  2013                         6885993015
# 1   Merger/acquisition   NaN  2014                         7657417878
# 2   Merger/acquisition   NaN  2015                        10117764887
# 3   Merger/acquisition   NaN  2016                        14733541676
# 4   Merger/acquisition   NaN  2017                        27282738436

# %%
df3 = pd.read_csv ('newly-funded-artificial-intelligence-companies.csv')
df3.shape
# Out:
# (44, 4)

# %%
df3.dtypes
# Out:
# Entity                        object
# Code                          object
# Year                           int64
# Newly founded AI companies     int64
# dtype: object

# %%
df4 = pd.read_csv('My_data.csv')
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4706 entries, 0 to 4705
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job titiles        4706 non-null   object
#  1   AI Impact          4706 non-null   object
#  2   Tasks              4706 non-null   int64
#  3   AI models          4706 non-null   int64
#  4   AI_Workload_Ratio  4706 non-null   float64
#  5   Domain             4706 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 220.7+ KB

# %%
df4.columns
# Out:
# Index(['Job titiles', 'AI Impact', 'Tasks', 'AI models', 'AI_Workload_Ratio',
#        'Domain'],
#       dtype='object')

# %%
df4.shape
# Out:
# (4706, 6)

# %%
import pandas as pd

# Cargar el archivo Excel
file_path = 'isoc_eb_ai$defaultview_spreadsheet.xlsx'
excel_file = pd.ExcelFile(file_path)

# Obtener los nombres de las hojas
print(excel_file.sheet_names)
# Out:
# ['Summary', 'Structure', 'Sheet 1', 'Sheet 2', 'Sheet 3', 'Sheet 4', 'Sheet 5', 'Sheet 6', 'Sheet 7', 'Sheet 8', 'Sheet 9', 'Sheet 10', 'Sheet 11', 'Sheet 12', 'Sheet 13', 'Sheet 14', 'Sheet 15', 'Sheet 16', 'Sheet 17', 'Sheet 18', 'Sheet 19', 'Sheet 20']
# C:\Users\flore\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#df = pd.read_excel(file_path, sheet_name='Nombre_de_la_hoja')

df6 = pd.read_excel("isoc_eb_ai_defaultview_spreadsheet.xlsx", sheet_name=excel_file.sheet_names[2])

# %%
print(df5["Unnamed: 5"][19])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 5'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(df6["Unnamed: 5"][19])
#
# ...

# %%
df6["Data extracted on 09/10/2024 02:51:10 from [ESTAT]"]
# Out:
# 0                                             Dataset:
# 1                                        Last updated:
# 2                                                   NaN
# 3                                        Time frequency
# 4            Size classes in number of persons employed
# 5     Statistical classification of economic activit...
# 6                         Information society indicator
# 7                                       Unit of measure
# 8                                                   NaN
# 9                                                  TIME
# 10                                         GEO (Labels)
# 11            European Union - 27 countries (from 2020)
# 12    Euro area (EA11-1999, EA12-2001, EA13-2007, EA...
# 13                                              Belgium
# 14                                             Bulgaria
# 15                                              Czechia
# 16                                              Denmark
# ...

# %%
df7 = pd.read_excel("isoc_eb_ai_page_spreadsheet.xlsx", sheet_name='Sheet 1')
# Out:
# C:\Users\flore\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df7
# Out:
#    Data extracted on 09/10/2024 03:08:36 from [ESTAT]  \
# 0                                           Dataset:
# 1                                      Last updated:
# 2                                                 NaN
# 3                                      Time frequency
# 4          Size classes in number of persons employed
# 5   Statistical classification of economic activit...
# 6                       Information society indicator
# 7                                     Unit of measure
# 8                                                 NaN
# 9                                                TIME
# 10                                       GEO (Labels)
# 11          European Union - 27 countries (from 2020)
# 12          European Union - 28 countries (2013-2020)
# 13          European Union - 27 countries (2007-2013)
# 14          European Union - 15 countries (1995-2004)
# 15  Euro area (EA11-1999, EA12-2001, EA13-2007, EA...
# ...
